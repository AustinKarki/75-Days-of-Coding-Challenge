# %% [markdown]
# <a href="https://colab.research.google.com/github/AustinKarki/75-Days-of-Coding-Challenge/blob/main/JobPosting_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

df=pd.read_csv("/content/drive/MyDrive/Techaxis/jobstreet_all_job_dataset.csv")
df
# Out:
#            job_id                                     job_title  \
# 0      74630583.0              Procurement Executive (Contract)
# 1      74660602.0                  Account Executive/ Assistant
# 2      74655679.0  Data Analyst - Asset Management, SPX Express
# 3      74657624.0                              Service Engineer
# 4      74679363.0                          Purchasing Executive
# ...           ...                                           ...
# 59301  76653277.0                    Marketing Specialist, APAC
# 59302  76674488.0                    Talent Acquisition Partner
# 59303  76658887.0                     Motor Insurance Executive
# 59304  76653289.0               Banca Specialist (Klang Valley)
# 59305  76643160.0                             Software Engineer
#
#                                                 company  \
# 0                 Coca-Cola Bottlers (Malaysia) Sdn Bhd
# 1                    Acoustic & Lighting System Sdn Bhd
# ...

# %%
df.shape
# Out:
# (59306, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59306 entries, 0 to 59305
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        59306 non-null  float64
#  1   job_title     59306 non-null  object
#  2   company       59306 non-null  object
#  3   descriptions  59306 non-null  object
#  4   location      59306 non-null  object
#  5   category      59306 non-null  object
#  6   subcategory   59306 non-null  object
#  7   role          57370 non-null  object
#  8   type          59306 non-null  object
#  9   salary        26641 non-null  object
#  10  listingDate   59306 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 5.0+ MB

# %%
df.describe()
# Out:
#              job_id
# count  5.930600e+04
# mean   7.497790e+07
# std    9.319422e+05
# min    7.134223e+07
# 25%    7.433293e+07
# 50%    7.478895e+07
# 75%    7.572671e+07
# max    7.669411e+07

# %%
df.head(5)
# Out:
#        job_id                                     job_title  \
# 0  74630583.0              Procurement Executive (Contract)
# 1  74660602.0                  Account Executive/ Assistant
# 2  74655679.0  Data Analyst - Asset Management, SPX Express
# 3  74657624.0                              Service Engineer
# 4  74679363.0                          Purchasing Executive
#
#                                   company  \
# 0   Coca-Cola Bottlers (Malaysia) Sdn Bhd
# 1      Acoustic & Lighting System Sdn Bhd
# 2          Shopee Mobile Malaysia Sdn Bhd
# 3             Sun Medical Systems Sdn Bhd
# 4  Magnet Security & Automation Sdn. Bhd.
#
#                                         descriptions         location  \
# 0  Position Purpose\nManage aspects of procuremen...  Negeri Sembilan
# 1  We are looking for a Account Executive/ Assist...         Petaling
# 2  Performs detailed data analysis on existing sp...   Klang District
# ...

# %%
df.tail(5)
# Out:
#            job_id                        job_title  \
# 59301  76653277.0       Marketing Specialist, APAC
# 59302  76674488.0       Talent Acquisition Partner
# 59303  76658887.0        Motor Insurance Executive
# 59304  76653289.0  Banca Specialist (Klang Valley)
# 59305  76643160.0                Software Engineer
#
#                                                 company  \
# 59301                        Glory Global Solutions (M)
# 59302  PERSOLKELLY Workforce Solutions Malaysia Sdn Bhd
# 59303                          MRMC Consultants Sdn Bhd
# 59304                                      AmBank Group
# 59305                        Juris Technologies Sdn Bhd
#
#                                             descriptions      location  \
# 59301  MAIN RESPONSIBILITIES\nSupport the Asia Pacifi...  Kuala Lumpur
# 59302  Job Descriptions:\nPartner closely with HRBPs ...  Kuala Lumpur
# 59303  Objective:\nHighly motivated and customer-focu...  Kuala Lumpur
# ...

# %%
df.sample(5)
# Out:
#            job_id                                   job_title  \
# 24613  74339990.0  Senior Associate - HR Operations (Payroll)
# 6880   74356193.0                         Electrical Engineer
# 25942  74204137.0                            Project Engineer
# 25352  74277203.0           MAINTENANCE MECHANICAL SPECIALIST
# 52886  76446589.0                    Manager (Digitalization)
#
#                                         company  \
# 24613  DHL Asia Pacific Shared Services Sdn Bhd
# 6880                 Sphere Corporation Sdn Bhd
# 25942                     Energia Power Sdn Bhd
# 25352     ETONE GEOTECHNICAL (MALAYSIA) SDN BHD
# 52886                DEWAN FILHARMONIK PETRONAS
#
#                                             descriptions  \
# 24613  Description\nOverall Role Purpose\nProvides da...
# 6880   Sphere Corporation Sdn Bhd\nRole: Electrical E...
# 25942  Description\nJOB DESCRIPTION:\nProject Plannin...
# 25352  Description\n- Assembling, installing, and mai...
# ...

# %%
df.isnull().sum()
# Out:
# job_id              0
# job_title           0
# company             0
# descriptions        0
# location            0
# category            0
# subcategory         0
# role             1936
# type                0
# salary          32665
# listingDate         0
# dtype: int64

# %%
new=df.dropna()
new
# Out:
#            job_id                     job_title  \
# 1      74660602.0  Account Executive/ Assistant
# 3      74657624.0              Service Engineer
# 4      74679363.0          Purchasing Executive
# 6      74677110.0            Accounts Executive
# 9      74602737.0               Admin Assistant
# ...           ...                           ...
# 59297  76567802.0  Marketing Executive, Cruises
# 59300  76659690.0                 Hotel Manager
# 59301  76653277.0    Marketing Specialist, APAC
# 59302  76674488.0    Talent Acquisition Partner
# 59303  76658887.0     Motor Insurance Executive
#
#                                                 company  \
# 1                    Acoustic & Lighting System Sdn Bhd
# 3                           Sun Medical Systems Sdn Bhd
# 4                Magnet Security & Automation Sdn. Bhd.
# 6                             GENETEC TECHNOLOGY BERHAD
# 9                            Lein Hing Holdings Sdn Bhd
# ...

# %%
company=new.groupby(['company',"job_title"])
company_role=company["role"].value_counts()
company_role
# Out:
# company                         job_title                                       role
# "K" LINE LOGISTICS (M) SDN BHD  LOGISTICS EXECUTIVE                             logistics-executive        1
#                                 Ocean Operations Executive                      operations-executive       2
# (M) Trinitygroup sdn bhd        Sales Executive(RM3000-RM8000 Basic+Commisson)  sales-executive            1
# -                               Personal Assistant                              personal-assistant         1
# .                               MEDICAL SALES EXECUTIVE                         Medical-Sales-Executive    1
#                                                                                                           ..
# 安达可文化传播（上海）有限公司                 Administrator (Full Time-Work From Home)        administration-officer     1
# 帆软软件有限公司                        Sales Engineer (Kuala Lumpur)                   sales-engineer             1
# ...

# %%
job_role=new.groupby(["job_title"])["role"].value_counts()
job_role
# Out:
# job_title                                                                  role
# (FeDEX) CUSTOMER EXPERIENCE SPECIALIST (IMMEDIATE HIRING)                  customer-experience-specialist         1
# (Form 1-3 华语, B.Melayu, English) Academics Coach 课业教练 / Tuition Teacher老师  Tuition-Teacher                        1
# (INTERNSHIP) Project Management and Business Development Intern            business-development                   1
# (Internship) Marketing Executive                                           marketing-executive                    1
# (Internship) Software Developer                                            software-developer                     1
#                                                                                                                  ..
# 餐厅副经理 Restaurant Assistant Manager                                         restaurant-manager                     2
# ...

# %%
company_role=new.groupby(["company"])["role"].value_counts()
company_role
# Out:
# company                         role
# "K" LINE LOGISTICS (M) SDN BHD  operations-executive       2
#                                 logistics-executive        1
# (M) Trinitygroup sdn bhd        sales-executive            1
# -                               personal-assistant         1
# .                               Medical-Sales-Executive    1
#                                                           ..
# 安达可文化传播（上海）有限公司                 administration-officer     1
# 帆软软件有限公司                        sales-engineer             1
# 广东高义包装科技股份有限公司                  project-manager            1
# 蘇州萬麗織造有限公司                      general-manager            3
# 黎明幼儿园                           administration-officer     1
# Name: count, Length: 21519, dtype: int64

# %%
com=new["company"].value_counts()
com
# Out:
# company
# Private Advertiser                                  1027
# AGENSI PEKERJAAN JS STAFFING SERVICES SDN BHD        218
# Agensi Pekerjaan PERSOLKELLY Malaysia Sdn Bhd        199
# Michael Page International (Malaysia) Sdn Bhd        190
# PERSOLKELLY Workforce Solutions Malaysia Sdn Bhd     142
#                                                     ...
# VLEE RENOVATION & CONSTRUCTION SDN. BHD.               1
# Searix Solutions International Pte. Ltd.               1
# ICON PACKAGING SDN BHD                                 1
# InsureSmart                                            1
# MRMC Consultants Sdn Bhd                               1
# Name: count, Length: 10769, dtype: int64

# %%
job_loc=new.groupby(["location"])["job_title"].value_counts()
job_loc
# Out:
# location         job_title
# Alam Damai       Account Assistant                        1
#                  Assistant Marketing Manager              1
#                  Executive Assistant                      1
#                  Marketing Executive                      1
#                  PA Cum Sales                             1
#                                                          ..
# Wangsa Maju      F&B Operation Executive                  1
#                  Inside Tele sales specialist             1
#                  Marketing Executive (Yayasan Nurjiwa)    1
#                  Personal Assistant Cum Account           1
# Wangsa Melawati  Accounts Executive                       1
# Name: count, Length: 19651, dtype: int64

# %%
job_type=new.groupby(["type", "location"])["job_title"].value_counts()
job_type
# Out:
# type             location           job_title
# Casual/Vacation  Bandar Malaysia    CRM/ ERP developer                                                                  1
#                  Johor              Banking Sales Executive (Urgent Hiring I Basic up to 4k I Fresh Grad welcome) P7    1
#                  Kuala Lumpur       Internship for Financial Representative                                             2
#                                     Beauty Advisor (Skincare)                                                           1
#                                     Finance Intern                                                                      1
#                                                                                                                        ..
# Part time        Seremban District  Customer Service cum Admin Assistant                                                1
# ...

# %%
# pd.set_option('display.max_rows', None)  #max row
pd.reset_option('display.max_rows')

new["salary"].value_counts()
# Out:
# salary
# RM 3,000 – RM 4,500 per month    1467
# RM 3,500 – RM 5,000 per month    1220
# RM 4,000 – RM 6,000 per month    1219
# RM 2,500 – RM 3,500 per month    1070
# RM 3,000 – RM 4,000 per month     996
#                                  ...
# $6k - $12k p.m.                     1
# Competitive Salary                  1
# RM6k - RM10k                        1
# $1,800 – $2,700 per month           1
# RM 18000 - RM 20000                 1
# Name: count, Length: 1825, dtype: int64

# %%
new["listingDate"].unique()
# Out:
# array(['2024-03-22T06:52:57Z', '2024-03-22T05:32:09Z',
#        '2024-03-23T03:56:39Z', ..., '2024-06-18T06:45:54Z',
#        '2024-06-19T03:37:54Z', '2024-06-18T10:15:07Z'], dtype=object)

# %%
start='2024-03-21'
end= '2024-08-21'

new[new['listingDate'].between(start,end)]
# Out:
#            job_id                                job_title  \
# 1      74660602.0             Account Executive/ Assistant
# 3      74657624.0                         Service Engineer
# 4      74679363.0                     Purchasing Executive
# 6      74677110.0                       Accounts Executive
# 10     74677668.0  Clerical Assistant (Educational Centre)
# ...           ...                                      ...
# 59297  76567802.0             Marketing Executive, Cruises
# 59300  76659690.0                            Hotel Manager
# 59301  76653277.0               Marketing Specialist, APAC
# 59302  76674488.0               Talent Acquisition Partner
# 59303  76658887.0                Motor Insurance Executive
#
#                                                 company  \
# 1                    Acoustic & Lighting System Sdn Bhd
# 3                           Sun Medical Systems Sdn Bhd
# 4                Magnet Security & Automation Sdn. Bhd.
# ...

# %%
job_cate=new.groupby(["category"])["job_title"].value_counts()
job_cate
# Out:
# category           job_title
# Accounting         Account Executive                           399
#                    Accounts Executive                          266
#                    Account Assistant                           146
#                    Finance Executive                           120
#                    ACCOUNT EXECUTIVE                           107
#                                                               ...
# Trades & Services  [Senior/Junior] Air Cond Technician           1
#                    project manager(Printing and packaging ）      1
#                    service technician                            1
#                    聘请冷气技术人员 AIR COND SERVICE TECHNICIAN          1
#                    高级设备工程师MAINTENANCE SENIOR TECHNICIAN          1
# Name: count, Length: 15491, dtype: int64

# %%
job_cate_df = job_cate.reset_index()
merged_df = job_cate_df.merge(new, on=["category", "job_title"], how="left")
final_df = merged_df[["location", "category", "subcategory", "role", "type", "salary", "count"]]
final_df
# Out:
#                       location           category  \
# 0               Klang District         Accounting
# 1                  Hulu Langat         Accounting
# 2                  Hulu Langat         Accounting
# 3                     Selangor         Accounting
# 4                 Kuala Lumpur         Accounting
# ...                        ...                ...
# 25988     Kajang/Bangi/Serdang  Trades & Services
# 25989     Johor Bahru District  Trades & Services
# 25990             Kuala Lumpur  Trades & Services
# 25991                 Selangor  Trades & Services
# 25992  Kuala Selangor District  Trades & Services
#
#                                    subcategory                         role  \
# 0      Bookkeeping & Small Practice Accounting            account-executive
# 1      Bookkeeping & Small Practice Accounting            account-executive
# 2      Bookkeeping & Small Practice Accounting            account-executive
# ...
