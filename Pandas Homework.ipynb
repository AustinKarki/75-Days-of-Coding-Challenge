# %%
import pandas as pd
iris=pd.read_csv("/content/drive/MyDrive/Techaxis/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris["SepalLengthCm"].min()
# Out:
# 4.3

# %%
iris["SepalLengthCm"].max()
# Out:
# 7.9

# %%
iris["SepalLengthCm"].mean()
# Out:
# 5.843333333333334

# %%
iris["SepalLengthCm"].median()
# Out:
# 5.8

# %%
(iris["SepalLengthCm"] > 6.0).value_counts()
# Out:
# SepalLengthCm
# False    89
# True     61
# Name: count, dtype: int64

# %%
greater_sepal=iris.loc[iris["SepalLengthCm"] > 6.0]
greater_sepal
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 54    55            6.5           2.8            4.6           1.5
# 56    57            6.3           3.3            4.7           1.6
# ..   ...            ...           ...            ...           ...
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 54   Iris-versicolor
# 56   Iris-versicolor
# ..               ...
# ...

# %%
iris[(iris["Species"] == "Iris-virginica")].value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 101  6.3            3.3           6.0            2.5           Iris-virginica    1
# 138  6.4            3.1           5.5            1.8           Iris-virginica    1
# 128  6.1            3.0           4.9            1.8           Iris-virginica    1
# 129  6.4            2.8           5.6            2.1           Iris-virginica    1
# 130  7.2            3.0           5.8            1.6           Iris-virginica    1
# 131  7.4            2.8           6.1            1.9           Iris-virginica    1
# 132  7.9            3.8           6.4            2.0           Iris-virginica    1
# 133  6.4            2.8           5.6            2.2           Iris-virginica    1
# 134  6.3            2.8           5.1            1.5           Iris-virginica    1
# 135  6.1            2.6           5.6            1.4           Iris-virginica    1
# ...

# %%
filter=iris[(iris["Species"] == "Iris-virginica") & (iris["PetalWidthCm"] > 2.0)]
filter
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# ...

# %%
filter=iris.loc[(iris["Species"] == "Iris-virginica") & (iris["PetalWidthCm"] > 2.0)]
filter
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 102  103            7.1           3.0            5.9           2.1
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 109  110            7.2           3.6            6.1           2.5
# 112  113            6.8           3.0            5.5           2.1
# 114  115            5.8           2.8            5.1           2.4
# 115  116            6.4           3.2            5.3           2.3
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 120  121            6.9           3.2            5.7           2.3
# 124  125            6.7           3.3            5.7           2.1
# 128  129            6.4           2.8            5.6           2.1
# ...

# %%
a=iris.loc[(iris["SepalWidthCm"] < 3.0) & (iris["PetalLengthCm"] > 4.0)]
a
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 54    55            6.5           2.8            4.6           1.5
# 55    56            5.7           2.8            4.5           1.3
# 58    59            6.6           2.9            4.6           1.3
# 63    64            6.1           2.9            4.7           1.4
# 67    68            5.8           2.7            4.1           1.0
# 68    69            6.2           2.2            4.5           1.5
# 72    73            6.3           2.5            4.9           1.5
# 73    74            6.1           2.8            4.7           1.2
# 74    75            6.4           2.9            4.3           1.3
# 76    77            6.8           2.8            4.8           1.4
# 78    79            6.0           2.9            4.5           1.5
# 83    84            6.0           2.7            5.1           1.6
# 87    88            6.3           2.3            4.4           1.3
# ...

# %%
b=iris.loc[(iris["Species"] == "Iris-setosa") & ((iris["SepalLengthCm"] < 5.5) & (iris["SepalLengthCm"] > 4.5))]
b
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
c=iris["PetalLengthCm"].mean()
d=iris["PetalLengthCm"].median()
print(f"Mean of PetalLengthCm is {c:.2f}")
print(f"Median of PetalLengthCm is {d:.2f}")
# Out:
# Mean of PetalLengthCm is 3.76
# Median of PetalLengthCm is 4.35

# %%
(iris["Species"] == "Iris-versicolor").value_counts()
# Out:
# Species
# False    100
# True      50
# Name: count, dtype: int64

# %%
t=iris["SepalWidthCm"].max()
t
# Out:
# 4.4

# %%
r=iris.loc[iris["SepalWidthCm"]==(iris["SepalWidthCm"].max())]
r
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa

# %%
iris["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
